# %%
import matplotlib.pyplot as plt

# Sizes and corresponding average execution times and normalized performance
sizes = list(range(500, 10001, 500))
execution_times = [
    0.102891, 0.409108, 0.913097, 1.639355, 2.582648,
    3.732378, 5.078820, 6.618839, 8.401814, 10.386791,
    12.533296, 14.969674, 18.050379, 20.896803, 23.827191,
    26.458763, 29.815031, 33.694487, 38.366459, 35.314912
]
normalized_performance = [
    485952096.786107, 488867987.066508, 492828145.787765, 487996863.156164,
    483999443.052161, 482266265.635474, 482395555.061652, 483468475.362522,
    482038782.674255, -345624988.783832, -202654959.397751, -92850021.641085,
    -7752446.195174, 57906723.646610, 111639906.931204, 159117995.968020,
    -91560167.105782, -29080994.461088, 22679466.590122, 79856657.040516
]

# Plotting execution times
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.plot(sizes, execution_times, marker='o', color='b', label='Execution Time (s)')
plt.title('Execution Time vs. Matrix Size')
plt.xlabel('Matrix Size')
plt.ylabel('Execution Time (seconds)')
plt.grid()
plt.legend()

# Plotting normalized performance
plt.subplot(1, 2, 2)
plt.plot(sizes, normalized_performance, marker='o', color='r', label='Normalized Performance (ops/s)')
plt.title('Normalized Performance vs. Matrix Size')
plt.xlabel('Matrix Size')
plt.ylabel('Normalized Performance (ops/s)')
plt.grid()
plt.legend()

plt.tight_layout()
plt.show()
